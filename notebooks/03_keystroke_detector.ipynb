# %% [markdown]
# # 03. Keystroke Dynamics Biometric Detector
#
# This notebook focuses on the CMU Keystroke Dynamics dataset. It demonstrates profiling genuine typing rhythm patterns using Scaled Manhattan Distance and Isolation Forest model training, evaluating performance via the Equal Error Rate (EER) metric.
