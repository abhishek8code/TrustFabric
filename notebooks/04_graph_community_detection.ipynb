# %% [markdown]
# # 04. Cross-Channel Graph Community Detection
#
# This notebook demonstrates building the customer device-IP sharing NetworkX graph and running Louvain community detection to identify and propagate risk across coordinated fraud rings.
