# %% [markdown]
# # 02. LightGBM Transaction Fraud Model Training
#
# This notebook covers the training of the LightGBM classifier on the engineered IEEE-CIS dataset features, including the 'UID trick' to group transactions by client-identity baselines, handling extreme class imbalance, and model persistence.
