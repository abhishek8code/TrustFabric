# %% [markdown]
# # 01. IEEE-CIS Fraud Detection - Exploratory Data Analysis (EDA)
#
# This notebook explores the IEEE-CIS fraud detection dataset, analyzing transaction amounts, card types, email domains, and identity properties to identify patterns indicative of fraudulent activity.
